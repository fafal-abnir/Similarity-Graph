# %%
import pandas as pd
import networkx as nx
import numpy as np

# %%
# trans_df = pd.read_csv("../data/creditcard.csv")
# sim_graph_df = pd.read_csv("../data/graph.csv")
trans_df = pd.read_csv("./trans_fraud_similarity")

# %%
trans_df["Class"].corr(trans_df["inversed_sim"])
# Out:
# 0.0009982261083723168

# %%
trans_df2 = pd.read_csv("./trans_fraud_similarity2")

trans_df2["Class"].corr(trans_df2["inversed_sim"])
# Out:
# -9.411388519462459e-06

# %%
trans_df2[trans_df2["Class"]==1]
# Out:
#         Unnamed: 0      Time        V1        V2        V3        V4  \
# 541            541     406.0 -2.312227  1.951992 -1.609851  3.997906
# 623            623     472.0 -3.043541 -3.157307  1.088463  2.288644
# 4920          4920    4462.0 -2.303350  1.759247 -0.359745  2.330243
# 6108          6108    6986.0 -4.397974  1.358367 -2.592844  2.679787
# 6329          6329    7519.0  1.234235  3.019740 -4.304597  4.732795
# ...            ...       ...       ...       ...       ...       ...
# 279863      279863  169142.0 -1.927883  1.125653 -4.518331  1.749293
# 280143      280143  169347.0  1.378559  1.289381 -5.004247  1.411850
# 280149      280149  169351.0 -0.676143  1.126366 -2.213700  0.468308
# 281144      281144  169966.0 -3.113832  0.585864 -5.399730  1.817092
# 281674      281674  170348.0  1.991976  0.158476 -2.583441  0.408670
#
#               V5        V6        V7        V8  ...       V22       V23  \
# ...

# %%
trans_df2[trans_df2["Class"]==0]
# Out:
#         Unnamed: 0      Time         V1         V2        V3        V4  \
# 0                0       0.0  -1.359807  -0.072781  2.536347  1.378155
# 1                1       0.0   1.191857   0.266151  0.166480  0.448154
# 2                2       1.0  -1.358354  -1.340163  1.773209  0.379780
# 3                3       1.0  -0.966272  -0.185226  1.792993 -0.863291
# 4                4       2.0  -1.158233   0.877737  1.548718  0.403034
# ...            ...       ...        ...        ...       ...       ...
# 284802      284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656
# 284803      284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589
# 284804      284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828
# 284805      284805  172788.0  -0.240440   0.530483  0.702510  0.689799
# 284806      284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271
#
#               V5        V6        V7        V8  ...       V22       V23  \
# ...

# %%
trans_df2 = pd.read_csv("./trans_fraud_extra_2022-10-26_01:32:42.csv")

trans_df2
# Out:
#      Unnamed: 0   Time        V1        V2        V3        V4        V5  \
# 0             0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1             1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2             2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3             3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4             4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
# ..          ...    ...       ...       ...       ...       ...       ...
# 995         995  751.0 -0.654892  0.608319  1.585102 -3.009429  0.037593
# 996         996  752.0 -2.101171 -0.227365  1.624668 -0.291123  1.902446
# 997         997  753.0 -1.248163  0.315246  3.708935  0.687280 -0.873071
# 998         998  755.0  1.374134 -1.767210 -0.433352 -2.229552  0.331135
# 999         999  755.0 -2.497436  1.402769  0.184840 -2.504117 -0.111803
#
#            V6        V7        V8  ...       V24       V25       V26  \
# ...

# %%
print(trans_df2["Class"].corr(trans_df2["inversed_dist"]))
# print(trans_df2["Class"].corr(trans_df2["community_risk"]))
print(trans_df2["Class"].corr(trans_df2["personalized_page_rank"]))
# Out:
# -9.411388519462459e-06
# -0.0024165318581646756
